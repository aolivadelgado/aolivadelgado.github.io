# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "proceedings.bib",
        "venuekey": "INPROCEEDINGS",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "pubs.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED Groshev_2025: " Energy-Aware Joint Orchestration of 5G and Robots: Experimen ... "
# SUCESSFULLY PARSED Baldoni_2024: " Data-Centric Service-Based Architecture for Edge-Native 6G N ... "
# SUCESSFULLY PARSED Rojas_2024: " Beyond Multi-Access Edge Computing: Essentials to Realize a  ... "
# SUCESSFULLY PARSED Picazo_Mart_nez_2024: " IEEE 802.11az Indoor Positioning with mmWave  "
# SUCESSFULLY PARSED Rico_Menendez_2025: " Experimentation on A Wireless Multi-Domain Deterministic Net ... "
# SUCESSFULLY PARSED Calvillo_Fernandez_2025: " Attention to Virtualization: Making Network Digital Twins aw ... "
# SUCESSFULLY PARSED Mart_n_P_rez_2023: " Choose, Not Hoard: Information-to-Model Matching for Artific ... "
# SUCESSFULLY PARSED Antevski_2021: " A 5G-Based eHealth Monitoring and Emergency Response System: ... "
# SUCESSFULLY PARSED Groshev_2022: " FoReCo: A Forecast-Based Recovery Mechanism for Real-Time Re ... "
# SUCESSFULLY PARSED Malandrino_2023: " Network Support for High-Performance Distributed Machine Lea ... "
# SUCESSFULLY PARSED Groshev_2023: " Edge robotics: are we ready? an experimental evaluation of c ... "
# SUCESSFULLY PARSED Groshev_2021_1: " Dissecting the Impact of Information and Communication Techn ... "
# SUCESSFULLY PARSED Baldoni_2023: " Managing the Far-Edge: Are Today’s Centralized Solutions a G ... "
# SUCESSFULLY PARSED Antevski_2020: " On the integration of NFV and MEC technologies: architecture ... "
# SUCESSFULLY PARSED Nemeth_2022: " Delay and Reliability-Constrained VNF Placement on Mobile an ... "
# SUCESSFULLY PARSED Guimaraes_2021: " DEEP: A Vertical-Oriented Intelligent and Automated Platform ... "
# SUCESSFULLY PARSED Gonzalez_Diaz_S_2021: " Stateless Flow-Zone Switching Using Software-Defined Address ... "
# SUCESSFULLY PARSED Cominardi_2020: " Adaptive Telemetry for Software-Defined Mobile Networks  "
# SUCESSFULLY PARSED Mourad_2020: " A Baseline Roadmap for Advanced Wireless Research Beyond 5G  "
# SUCESSFULLY PARSED Martin_Perez_2019: " Modeling Mobile Edge Computing Deployments for Low Latency M ... "
# SUCESSFULLY PARSED Gonzalez_Diaz_2021: " Integrating Fronthaul and Backhaul Networks: Transport Chall ... "
# SUCESSFULLY PARSED Molner_2019: " Optimization of an integrated fronthaul/backhaul network und ... "
# SUCESSFULLY PARSED Cominardi_2018: " Experimental evaluation of SDN-based service provisioning in ... "
# SUCESSFULLY PARSED Mangues_Bafalluy_2019: " Experimental framework and evaluation of the 5G-Crosshaul co ... "
# SUCESSFULLY PARSED Cominardi_2017: " Distributed mobility management solutions for next mobile ne ... "
# SUCESSFULLY PARSED Costa_Perez_2017: " 5G-Crosshaul: An SDN/NFV Integrated Fronthaul/Backhaul Trans ... "
# SUCESSFULLY PARSED Li_2017: " 5G-Crosshaul Network Slicing: Enabling Multi-Tenancy in Mobi ... "
# SUCESSFULLY PARSED Gonz_lez_2016: " 5G‐Crosshaul: An SDN/NFV control and data plane architecture ... "
# SUCESSFULLY PARSED Cavaliere_2017: " Towards a unified fronthaul-backhaul data plane for 5G The 5 ... "
# SUCESSFULLY PARSED Sanchez_2016: " Experimental analysis of connectivity management in mobile o ... "
# SUCESSFULLY PARSED La_Oliva_2015: " Xhaul: toward an integrated fronthaul/backhaul architecture  ... "
# SUCESSFULLY PARSED de_la_Oliva_2016: " An overview of the CPRI specification and its application to ... "
# SUCESSFULLY PARSED Cicconetti_2015: " Extremely dense wireless networks [Guest Editorial]  "
# SUCESSFULLY PARSED Donato_2015: " An openflow architecture for energy-aware traffic engineerin ... "
# SUCESSFULLY PARSED Giust_2015: " HDMM: deploying client and network-based distributed mobilit ... "
# SUCESSFULLY PARSED Giust_2014: " Analytic Evaluation and Experimental Validation of a Network ... "
# SUCESSFULLY PARSED Bernardos_2014: " An architecture for software defined wireless networking  "
# SUCESSFULLY PARSED Sanchez_2014: " On the implementation, deployment and evaluation of a networ ... "
# SUCESSFULLY PARSED Banchs_2014: " Performance Analysis and Algorithm Selection for Reliable Mu ... "
# SUCESSFULLY PARSED Groshev_2021: " Toward Intelligent Cyber-Physical Systems: Digital Twin Meet ... "
# SUCESSFULLY PARSED de_la_Oliva_2012_1: " Providing throughput guarantees in heterogeneous wireless me ... "
# SUCESSFULLY PARSED de_la_Oliva_2012_2: " Throughput and energy-aware routing for 802.11 based mesh ne ... "
# SUCESSFULLY PARSED de_la_Oliva_2012_3: " Client and network-based dual stack mobility management  "
# SUCESSFULLY PARSED de_la_Oliva_2011: " IP flow mobility: smart traffic offload for future wireless  ... "
# SUCESSFULLY PARSED la_Oliva_2011: " IEEE 802.21: Media independence beyond handover  "
# SUCESSFULLY PARSED Vidal_2011: " TRIM: An architecture for transparent IMS-based mobility  "
# SUCESSFULLY PARSED Vidal_2010: " Supporting mobility in an IMS-based P2P IPTV service: A proa ... "
# SUCESSFULLY PARSED Melia_2011: " IP Flow Mobility in PMIPv6 Based Networks: Solution Design a ... "
# SUCESSFULLY PARSED Serrano_2010: " FloorNet: Deployment and Evaluation of a Multihop Wireless 8 ... "
# SUCESSFULLY PARSED de_la_Oliva_2010: " Analytical characterization of failure recovery in REAP  "
# SUCESSFULLY PARSED De_La_Oliva_2008: " An overview of IEEE 802.21: media-independent handover servi ... "
# SUCESSFULLY PARSED Melia_2007_1: " Network controlled handovers: challenges and possibilities  "
# SUCESSFULLY PARSED Melia_2007: " Toward IP converged heterogeneous mobility: A network contro ... "
# SUCESSFULLY PARSED Calderon_2006: " Design and Experimental Evaluation of a Route Optimization S ... "
# SUCESSFULLY PARSED Zuniga_2013: " Distributed mobility management: A standards landscape  "
